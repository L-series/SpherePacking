# %%
#the code below generates at once all text files of a given level, weight and prec

# %%
# %%gp
# prec = 50000
# weight = 7/2
# weight2="7_2"
# tol=1/100000
# /*in case the weight is a half-integer, must have level multiple of 4. Also, will have to get rid of the weight in the filename, otherwise cant find directory due to /*/
# /*for(level=1,100, if(isprime(level)==1,imagfilenameds=concat("IMAG_DUAL_SPACE_L",Str(level));imagfilenameds=concat(imagfilenameds,"W");imagfilenameds=concat(imagfilenameds,Str(weight));imagfilenameds=concat(imagfilenameds,"P");imagfilenameds=concat(imagfilenameds,Str(prec));imagfilenameds=concat(imagfilenameds,".txt");realfilenameds=concat("REAL_DUAL_SPACE_L",Str(level));realfilenameds=concat(realfilenameds,"W");realfilenameds=concat(realfilenameds,Str(weight));realfilenameds=concat(realfilenameds,"P");realfilenameds=concat(realfilenameds,Str(prec));realfilenameds=concat(realfilenameds,".txt");imagfilenamefs=concat("IMAG_FULL_SPACE_L",Str(level));imagfilenamefs=concat(imagfilenamefs,"W");imagfilenamefs=concat(imagfilenamefs,Str(weight));imagfilenamefs=concat(imagfilenamefs,"P");imagfilenamefs=concat(imagfilenamefs,Str(prec));imagfilenamefs=concat(imagfilenamefs,".txt");realfilenamefs=concat("REAL_FULL_SPACE_L",Str(level));realfilenamefs=concat(realfilenamefs,"W");realfilenamefs=concat(realfilenamefs,Str(weight));realfilenamefs=concat(realfilenamefs,"P");realfilenamefs=concat(realfilenamefs,Str(prec));realfilenamefs=concat(realfilenamefs,".txt");filenameds=concat("DUAL_SPACE_L",Str(level));filenameds=concat(filenameds,"W");filenameds=concat(filenameds,Str(weight));filenameds=concat(filenameds,"P");filenameds=concat(filenameds,Str(prec));filenameds=concat(filenameds,".txt");filenamefs=concat("FULL_SPACE_L",Str(level));filenamefs=concat(filenamefs,"W");filenamefs=concat(filenamefs,Str(weight));filenamefs=concat(filenamefs,"P");filenamefs=concat(filenamefs,Str(prec));filenamefs=concat(filenamefs,".txt");list_of_spaces = List([]);list_generators = List([]);list_dual_generators=List([]);list_generators_real=List([]);list_generators_imaginary=List([]);list_dual_generators_real=List([]);list_dual_generators_imaginary=List([]);for(i=1,level-1, if(gcd(i,level)==1, mf(i)=mfinit([level,weight,Mod(i,level)])));for(i=1,level-1,if(gcd(i,level)==1, listput(list_of_spaces,mf(i))));for(i=1,level-1, if(gcd(i,level)==1, B(i)=mfbasis(mf(i))));for(i=1,level-1,if(gcd(i,level)==1,for(j=1,length(B(i)),listput(list_generators,mfembed(B(i)[j],mfcoefs(B(i)[j],prec))))));for(i=1,level-1,if(gcd(i,level)==1,for(j=1,length(B(i)),listput(list_dual_generators,mfslashexpansion(mf(i),B(i)[j],[0,-1;level,0],prec,0,&P)))));for(i=1,length(list_generators),write(filenamefs,list_generators[i]));for(i=1,length(list_dual_generators),write(filenameds,list_dual_generators[i]));for(i=1,length(list_generators),write(realfilenamefs,real(list_generators[i])));for(i=1,length(list_generators),write(imagfilenamefs,imag(list_generators[i])));for(i=1,length(list_dual_generators),write(realfilenameds,real(list_dual_generators[i])));for(i=1,length(list_dual_generators),write(imagfilenameds,imag(list_dual_generators[i])))))*/
# /*for(level=101,110, imagfilenameds=concat("IMAG_DUAL_SPACE_L",Str(level));imagfilenameds=concat(imagfilenameds,"W");imagfilenameds=concat(imagfilenameds,Str(weight));imagfilenameds=concat(imagfilenameds,"P");imagfilenameds=concat(imagfilenameds,Str(prec));imagfilenameds=concat(imagfilenameds,".txt");realfilenameds=concat("REAL_DUAL_SPACE_L",Str(level));realfilenameds=concat(realfilenameds,"W");realfilenameds=concat(realfilenameds,Str(weight));realfilenameds=concat(realfilenameds,"P");realfilenameds=concat(realfilenameds,Str(prec));realfilenameds=concat(realfilenameds,".txt");imagfilenamefs=concat("IMAG_FULL_SPACE_L",Str(level));imagfilenamefs=concat(imagfilenamefs,"W");imagfilenamefs=concat(imagfilenamefs,Str(weight));imagfilenamefs=concat(imagfilenamefs,"P");imagfilenamefs=concat(imagfilenamefs,Str(prec));imagfilenamefs=concat(imagfilenamefs,".txt");realfilenamefs=concat("REAL_FULL_SPACE_L",Str(level));realfilenamefs=concat(realfilenamefs,"W");realfilenamefs=concat(realfilenamefs,Str(weight));realfilenamefs=concat(realfilenamefs,"P");realfilenamefs=concat(realfilenamefs,Str(prec));realfilenamefs=concat(realfilenamefs,".txt");filenameds=concat("DUAL_SPACE_L",Str(level));filenameds=concat(filenameds,"W");filenameds=concat(filenameds,Str(weight));filenameds=concat(filenameds,"P");filenameds=concat(filenameds,Str(prec));filenameds=concat(filenameds,".txt");filenamefs=concat("FULL_SPACE_L",Str(level));filenamefs=concat(filenamefs,"W");filenamefs=concat(filenamefs,Str(weight));filenamefs=concat(filenamefs,"P");filenamefs=concat(filenamefs,Str(prec));filenamefs=concat(filenamefs,".txt");list_of_spaces = List([]);list_generators = List([]);list_dual_generators=List([]);list_generators_real=List([]);list_generators_imaginary=List([]);list_dual_generators_real=List([]);list_dual_generators_imaginary=List([]);for(i=1,level-1, if(gcd(i,level)==1, mf(i)=mfinit([level,weight,Mod(i,level)])));for(i=1,level-1,if(gcd(i,level)==1, listput(list_of_spaces,mf(i))));for(i=1,level-1, if(gcd(i,level)==1, B(i)=mfbasis(mf(i))));for(i=1,level-1,if(gcd(i,level)==1,for(j=1,length(B(i)),listput(list_generators,mfembed(B(i)[j],mfcoefs(B(i)[j],prec))))));for(i=1,level-1,if(gcd(i,level)==1,for(j=1,length(B(i)),listput(list_dual_generators,mfslashexpansion(mf(i),B(i)[j],[0,-1;level,0],prec,0,&P)))));for(i=1,length(list_generators),write(filenamefs,list_generators[i]));for(i=1,length(list_dual_generators),write(filenameds,list_dual_generators[i]));for(i=1,length(list_generators),write(realfilenamefs,real(list_generators[i])));for(i=1,length(list_generators),write(imagfilenamefs,imag(list_generators[i])));for(i=1,length(list_dual_generators),write(realfilenameds,real(list_dual_generators[i])));for(i=1,length(list_dual_generators),write(imagfilenameds,imag(list_dual_generators[i]))))*/
#
# for(level=1,20,\
#     if((level%4)==0, \
#        imagfilenameds=concat("IMAG_DUAL_SPACE_L",Str(level));\
#        imagfilenameds=concat(imagfilenameds,"W");\
#        imagfilenameds=concat(imagfilenameds,Str(weight2));\
#        imagfilenameds=concat(imagfilenameds,"P");\
#        imagfilenameds=concat(imagfilenameds,Str(prec));\
#        imagfilenameds=concat(imagfilenameds,".txt");\
#        realfilenameds=concat("REAL_DUAL_SPACE_L",Str(level));\
#        realfilenameds=concat(realfilenameds,"W");\
#        realfilenameds=concat(realfilenameds,Str(weight2));\
#        realfilenameds=concat(realfilenameds,"P");\
#        realfilenameds=concat(realfilenameds,Str(prec));\
#        realfilenameds=concat(realfilenameds,".txt");\
#        imagfilenamefs=concat("IMAG_FULL_SPACE_L",Str(level));\
#        imagfilenamefs=concat(imagfilenamefs,"W");\
#        imagfilenamefs=concat(imagfilenamefs,Str(weight2));\
#        imagfilenamefs=concat(imagfilenamefs,"P");\
#        imagfilenamefs=concat(imagfilenamefs,Str(prec));\
#        imagfilenamefs=concat(imagfilenamefs,".txt");\
#        realfilenamefs=concat("REAL_FULL_SPACE_L",Str(level));\
#        realfilenamefs=concat(realfilenamefs,"W");\
#        realfilenamefs=concat(realfilenamefs,Str(weight2));\
#        realfilenamefs=concat(realfilenamefs,"P");\
#        realfilenamefs=concat(realfilenamefs,Str(prec));\
#        realfilenamefs=concat(realfilenamefs,".txt");\
#        filenameds=concat("DUAL_SPACE_L",Str(level));\
#        filenameds=concat(filenameds,"W");\
#        filenameds=concat(filenameds,Str(weight2));\
#        filenameds=concat(filenameds,"P");\
#        filenameds=concat(filenameds,Str(prec));\
#        filenameds=concat(filenameds,".txt");\
#        filenamefs=concat("FULL_SPACE_L",Str(level));\
#        filenamefs=concat(filenamefs,"W");\
#        filenamefs=concat(filenamefs,Str(weight2));\
#        filenamefs=concat(filenamefs,"P");\
#        filenamefs=concat(filenamefs,Str(prec));\
#        filenamefs=concat(filenamefs,".txt");\
#        list_of_spaces = List([]);\
#        list_generators = List([]);\
#        list_dual_generators=List([]);\
#        list_generators_real=List([]);\
#        list_generators_imaginary=List([]);\
#        list_dual_generators_real=List([]);\
#        list_dual_generators_imaginary=List([]);\
#        for(i=1,level-1, \
#            if(gcd(i,level)==1,\
#               mf(i)=mfinit([level,weight,Mod(i,level)])));\
#        for(i=1,level-1,\
#            if(gcd(i,level)==1,\
#               listput(list_of_spaces,mf(i))));\
#        for(i=1,level-1,\
#            if(gcd(i,level)==1,\
#               B(i)=mfbasis(mf(i))));\
#        for(i=1,level-1,\
#            if(gcd(i,level)==1,\
#               for(j=1,length(B(i)),\
#                   listput(list_generators,mfembed(B(i)[j],mfcoefs(B(i)[j],prec))))));\
#        for(i=1,level-1,\
#            if(gcd(i,level)==1,\
#               for(j=1,length(B(i)),\
#                   listput(list_dual_generators,mfslashexpansion(mf(i),B(i)[j],[0,-1;level,0],prec,0,&P)))));\
#        for(i=1,length(list_dual_generators),\
#           for(j=1,length(list_dual_generators[i]),\
#              list_dual_generators[i][j]=((-I)^(-weight))*list_dual_generators[i][j]));\
#        for(i=1,length(list_generators),\
#            listput(list_generators_real,real(list_generators[i])));\
#        for(i=1,length(list_generators_real),\
#            for(j=1,length(list_generators_real[i]),\
#                if(abs(list_generators_real[i][j])<tol,\
#                   list_generators_real[i][j]=0)));\
#        for(i=1,length(list_generators),\
#            listput(list_generators_imaginary,imag(list_generators[i])));\
#        for(i=1,length(list_generators_imaginary),\
#            for(j=1,length(list_generators_imaginary[i]),\
#                if(abs(list_generators_imaginary[i][j])<tol,\
#                   list_generators_imaginary[i][j]=0)));\
#        for(i=1,length(list_dual_generators),\
#            listput(list_dual_generators_real,real(list_dual_generators[i])));\
#        for(i=1,length(list_dual_generators_real),\
#            for(j=1,length(list_dual_generators_real[i]),\
#                if(abs(list_dual_generators_real[i][j])<tol,\
#                   list_dual_generators_real[i][j]=0)));\
#        for(i=1,length(list_dual_generators),\
#            listput(list_dual_generators_imaginary,imag(list_dual_generators[i])));\
#        for(i=1,length(list_dual_generators_imaginary),\
#            for(j=1,length(list_dual_generators_imaginary[i]),\
#                if(abs(list_dual_generators_imaginary[i][j])<tol,\
#                   list_dual_generators_imaginary[i][j]=0)));\
#        for(i=1,length(list_generators),\
#            write(filenamefs,list_generators[i]));\
#        for(i=1,length(list_dual_generators),\
#            write(filenameds,list_dual_generators[i]));\
#        for(i=1,length(list_generators),\
#            write(realfilenamefs,list_generators_real[i]));\
#        for(i=1,length(list_generators),\
#            write(imagfilenamefs,list_generators_imaginary[i]));\
#        for(i=1,length(list_dual_generators),\
#            write(realfilenameds,list_dual_generators_real[i]));\
#        for(i=1,length(list_dual_generators),\
#            write(imagfilenameds,list_dual_generators_imaginary[i]))))
